# %%
#import essentials
import pandas as pd
import numpy as np

from analysis_preprocess import checkcorrelation, checkmissing, checkallcatvaluecounts, PrincipalComponentAnalysis, MultipleCorrespondenceAnalysis

import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

data = pd.read_csv('train.csv')
# Out:
# C:\Windows\Temp\ipykernel_14232\3633575544.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# # EDA(Exploratory Data Analysis)

# %%
    print(data.info())
    print("=====================================")
    print("Number of rows:")
    print(len(data))
    print("=====================================")
    print("Number if unique id:")
    print(data['Id'].nunique())
    print("=====================================")
    print("Number of unique houses:")
    print(len(data.drop(['Id','SalePrice','SaleCondition','SaleType'],axis = 1).drop_duplicates()))
    print("=====================================")
    print(data.sample(10))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     588 non-null    object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB
# None
# =====================================
# Number of rows:
# 1460
# =====================================
# Number if unique id:
# 1460
# =====================================
# Number of unique houses:
# 1460
# =====================================
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1144  1145         190       RL         60.0    12180   Pave   NaN      Reg
# 472    473         180       RM         35.0     3675   Pave   NaN      Reg
# 952    953          85       RL         60.0     7200   Pave   NaN      Reg
# 1331  1332          80       RL         55.0    10780   Pave   NaN      IR1
# 518    519          60       RL          NaN     9531   Pave   NaN      IR1
# 463    464          70       RL         74.0    11988   Pave   NaN      IR1
# 1002  1003          20       RL         75.0    11957   Pave   NaN      IR1
# 971    972         160       RL         36.0     2268   Pave   NaN      Reg
# 1217  1218          20       FV         72.0     8640   Pave   NaN      Reg
# 66      67          20       RL          NaN    19900   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1144         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 472          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 952          Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1331         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 518          Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 463          HLS    AllPub  ...        0    NaN    NaN         NaN       0
# 1002         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 971          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1217         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 66           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1144      7   2010        WD         Normal      80000
# 472       6   2008        WD         Normal     148000
# 952       4   2009        WD         Normal     133900
# 1331      7   2006        WD         Normal     132500
# 518       5   2007        WD         Normal     211000
# 463       8   2008        WD         Normal     188700
# 1002      7   2008        WD         Normal     232000
# 971       7   2009        WD         Normal     173000
# 1217      9   2009       New        Partial     229456
# 66        7   2010        WD         Normal     180000
#
# [10 rows x 81 columns]

# %% [markdown]
# All of the records are unique despite dropping SalePrice, SaleCondition, and SaleType to specifically look at the characteristics of the house.

# %% [markdown]
# This means, no house is the same with one and another.

# %% [markdown]
# From the .info(), we notice that some attributes have very large missing values. To understand the intuition behind these missing values, we need to separate them first by the data types (e.g., numeric vs categorical) to ease our work

# %%
#Before continuing, drop "Id" since it is an irrelevant column
data.drop(columns = ['Id'],inplace = True)

# %% [markdown]
# # Exploring Numerical Variables (and categorical variables along the way)

# %% [markdown]
# We need to see the missing values present in the numeric variables

# %%
numofmv = data.select_dtypes(exclude = 'object').isnull().sum()/len(data)
print('Columns that has missing values:\n{}'.format(numofmv[numofmv>0]))

#print('Columns that has large missing values:\n{}'.format(numofmv[numofmv>0.3].sort_values(ascending=False)))
# Out:
# Columns that has missing values:
# LotFrontage    0.177397
# MasVnrArea     0.005479
# GarageYrBlt    0.055479
# dtype: float64

# %% [markdown]
# it seems that there are 3 numerical variables that has missing values.

# %% [markdown]
# #### Checking lotfrontage

# %%
data['LotFrontage'].describe()
# Out:
# count    1201.000000
# mean       70.049958
# std        24.284752
# min        21.000000
# 25%        59.000000
# 50%        69.000000
# 75%        80.000000
# max       313.000000
# Name: LotFrontage, dtype: float64

# %%
#on what conditions does lotfrontage has missing value
data[data['LotFrontage'].isna()]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 7             60       RL          NaN    10382   Pave   NaN      IR1
# 12            20       RL          NaN    12968   Pave   NaN      IR2
# 14            20       RL          NaN    10920   Pave   NaN      IR1
# 16            20       RL          NaN    11241   Pave   NaN      IR1
# 24            20       RL          NaN     8246   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1429          20       RL          NaN    12546   Pave   NaN      IR1
# 1431         120       RL          NaN     4928   Pave   NaN      IR1
# 1441         120       RM          NaN     4426   Pave   NaN      Reg
# 1443          30       RL          NaN     8854   Pave   NaN      Reg
# 1446          20       RL          NaN    26142   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# 7            Lvl    AllPub    Corner  ...        0    NaN    NaN        Shed
# 12           Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 14           Lvl    AllPub    Corner  ...        0    NaN   GdWo         NaN
# 16           Lvl    AllPub   CulDSac  ...        0    NaN    NaN        Shed
# 24           Lvl    AllPub    Inside  ...        0    NaN  MnPrv         NaN
# ...          ...       ...       ...  ...      ...    ...    ...         ...
# 1429         Lvl    AllPub    Corner  ...        0    NaN    NaN         NaN
# 1431         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1441         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1443         Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# 1446         Lvl    AllPub   CulDSac  ...        0    NaN    NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 7        350     11    2009        WD         Normal     200000
# 12         0      9    2008        WD         Normal     144000
# 14         0      5    2008        WD         Normal     157000
# 16       700      3    2010        WD         Normal     149000
# 24         0      5    2010        WD         Normal     154000
# ...      ...    ...     ...       ...            ...        ...
# 1429       0      4    2007        WD         Normal     182900
# 1431       0     10    2009        WD         Normal     143750
# 1441       0      5    2008        WD         Normal     149300
# 1443       0      5    2009        WD         Normal     121000
# 1446       0      4    2010        WD         Normal     157900
#
# [259 rows x 80 columns]

# %%
#anything in common when LotFrontage is NA?
commonfeature = data[data['LotFrontage'].isna()].nunique()
commonfeature[commonfeature == 1]
# Out:
# PoolQC    1
# dtype: int64

# %%
data[data['LotFrontage'].isna()][['LotFrontage','PoolQC','PoolArea']]
# Out:
#       LotFrontage PoolQC  PoolArea
# 7             NaN    NaN         0
# 12            NaN    NaN         0
# 14            NaN    NaN         0
# 16            NaN    NaN         0
# 24            NaN    NaN         0
# ...           ...    ...       ...
# 1429          NaN    NaN         0
# 1431          NaN    NaN         0
# 1441          NaN    NaN         0
# 1443          NaN    NaN         0
# 1446          NaN    NaN         0
#
# [259 rows x 3 columns]

# %%
data['Neighborhood'].isnull().sum()
# Out:
# 0

# %% [markdown]
# It shows that only value from "PoolQC" feature is static when LotFrontage is missing. PoolQC is NaN when there is no pool in the house. But, it does not make sense because the availability of the pool does not affect distance from street. It's not possible to drop these values since in the future we might encounter these missing values again.

# %% [markdown]
# Since we have data about the style of the house of the area that the house is located, we can try to fill the missing values by the neigborhood median. This intuition is driven by the condition of the landscape of each neighborhood. For example, depending on the landscape, houses in 강남 versus houses in 청량리 will have a difference of "house to street" distance. Part of it is due to the neighborhood landscape, condition, etc.

# %%
LFneighborhood = data.groupby('Neighborhood')['LotFrontage'].median().to_dict()
data['LotFrontage'] = data.apply(lambda row: LFneighborhood[row['Neighborhood']] if np.isnan(row['LotFrontage']) else row['LotFrontage'], axis=1)

# %% [markdown]
# #### Checking MasVnrArea

# %% [markdown]
# MasVnrArea is directly dependent with MasVnrType. Could it be that missing MasVnrArea means no masonry veneer available?

# %%
print("Does empty MasVnrArea means no masonry veneer available?")
display(data[data['MasVnrArea'].isna()][['MasVnrArea','MasVnrType']])
print("number of empty space but type is not None: {}".format(len(data[data['MasVnrArea'].isna()][['MasVnrArea','MasVnrType']])))
print("Does empty MasVnrType means no space reserved for masonry veneer?")
display(data[(data['MasVnrType'].isna()) & (data['MasVnrArea'] > 0)][['MasVnrType','MasVnrArea']])
print("number of empty type but has space: {}".format(len(data[(data['MasVnrType'].isna()) & (data['MasVnrArea'] > 0)][['MasVnrType','MasVnrArea']])))
# Out:
# Does empty MasVnrArea means no masonry veneer available?
#       MasVnrArea MasVnrType
# 234          NaN        NaN
# 529          NaN        NaN
# 650          NaN        NaN
# 936          NaN        NaN
# 973          NaN        NaN
# 977          NaN        NaN
# 1243         NaN        NaN
# 1278         NaN        NaN
# number of empty space but type is not None: 8
# Does empty MasVnrType means no space reserved for masonry veneer?
#      MasVnrType  MasVnrArea
# 624         NaN       288.0
# 773         NaN         1.0
# 1230        NaN         1.0
# 1300        NaN       344.0
# 1334        NaN       312.0
# number of empty type but has space: 5

# %% [markdown]
# The first statement shows that when the Area is not available, there's a tendency that the type is also not known. As for the other way around, in my opinion we can also try to impute it with the mode of the data.

# %%
data['MasVnrArea'] = data['MasVnrArea'].fillna(0)
data.loc[(data['MasVnrType'].isna()) & (data['MasVnrArea'] > 0), 'MasVnrType'] = data['MasVnrType'].mode()[0]
data['MasVnrType'] = data['MasVnrType'].fillna("None")

# %%
#sanity check
data.loc[(data['MasVnrType'] == 'None') & (data['MasVnrArea'] > 0), 'MasVnrType']
# Out:
# Series([], Name: MasVnrType, dtype: object)

# %% [markdown]
# #### Checking GarageYrBlt

# %% [markdown]
# GarageYrBlt is directly associated with the availability of the garage. Let's check that first

# %%
print('Check Data')
print('The length of data when GarageYrBlt is empty = the length of data when both GarageYrBlt and GarageType are empty:')
EmptyGarageYear = len(data[data['GarageYrBlt'].isna()][['GarageYrBlt','GarageType']])
EmptyGarageYear_GarageType = len(data[(data['GarageYrBlt'].isna())&(data['GarageType'].isna())][['GarageYrBlt','GarageType']])
print(EmptyGarageYear == EmptyGarageYear_GarageType)
# Out:
# Check Data
# The length of data when GarageYrBlt is empty = the length of data when both GarageYrBlt and GarageType are empty:
# True

# %% [markdown]
# It seems that GarageYear is only not available when there is no Garage. Let's impute this with zero.

# %%
data['GarageYrBlt'] = data['GarageYrBlt'].fillna(0)

# %% [markdown]
# #### Additional note on MSSubClass

# %% [markdown]
# If we observe MSSubClass, it is more similar to categorical variable than numerical variable. Convert this into str and then to object type.

# %%
data['MSSubClass'] = data['MSSubClass'].astype('str').astype('object')

# %% [markdown]
# #### Correlation and Engineering

# %% [markdown]
# I do feature engineering referring to the reference that Ineeji gave to me.

# %%
####in this phase will do engineering for numerical variables

#add more weight if the building has been remodel, especially if it's recently remodeled
data['YrBltAndRemod']=data['YearBuilt']+data['YearRemodAdd']

#captures the feeling of spaciness in the house
data['TotalSF']=data['TotalBsmtSF'] + data['1stFlrSF'] + data['2ndFlrSF']
data['Total_sqr_footage'] = (data['BsmtFinSF1'] + data['BsmtFinSF2'] +
                                 data['1stFlrSF'] + data['2ndFlrSF'])
data['Total_porch_sf'] = (data['OpenPorchSF'] + data['3SsnPorch'] +
                              data['EnclosedPorch'] + data['ScreenPorch'] +
                              data['WoodDeckSF'])
data['Total_Bathrooms'] = (data['FullBath'] + (0.5 * data['HalfBath']) +
                               data['BsmtFullBath'] + (0.5 * data['BsmtHalfBath']))

# %%
data.select_dtypes(exclude = 'object').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   LotFrontage        1460 non-null   float64
#  1   LotArea            1460 non-null   int64
#  2   OverallQual        1460 non-null   int64
#  3   OverallCond        1460 non-null   int64
#  4   YearBuilt          1460 non-null   int64
#  5   YearRemodAdd       1460 non-null   int64
#  6   MasVnrArea         1460 non-null   float64
#  7   BsmtFinSF1         1460 non-null   int64
#  8   BsmtFinSF2         1460 non-null   int64
#  9   BsmtUnfSF          1460 non-null   int64
#  10  TotalBsmtSF        1460 non-null   int64
#  11  1stFlrSF           1460 non-null   int64
#  12  2ndFlrSF           1460 non-null   int64
#  13  LowQualFinSF       1460 non-null   int64
#  14  GrLivArea          1460 non-null   int64
#  15  BsmtFullBath       1460 non-null   int64
#  16  BsmtHalfBath       1460 non-null   int64
#  17  FullBath           1460 non-null   int64
#  18  HalfBath           1460 non-null   int64
#  19  BedroomAbvGr       1460 non-null   int64
#  20  KitchenAbvGr       1460 non-null   int64
#  21  TotRmsAbvGrd       1460 non-null   int64
#  22  Fireplaces         1460 non-null   int64
#  23  GarageYrBlt        1460 non-null   float64
#  24  GarageCars         1460 non-null   int64
#  25  GarageArea         1460 non-null   int64
#  26  WoodDeckSF         1460 non-null   int64
#  27  OpenPorchSF        1460 non-null   int64
#  28  EnclosedPorch      1460 non-null   int64
#  29  3SsnPorch          1460 non-null   int64
#  30  ScreenPorch        1460 non-null   int64
#  31  PoolArea           1460 non-null   int64
#  32  MiscVal            1460 non-null   int64
#  33  MoSold             1460 non-null   int64
#  34  YrSold             1460 non-null   int64
#  35  SalePrice          1460 non-null   int64
#  36  YrBltAndRemod      1460 non-null   int64
#  37  TotalSF            1460 non-null   int64
#  38  Total_sqr_footage  1460 non-null   int64
#  39  Total_porch_sf     1460 non-null   int64
#  40  Total_Bathrooms    1460 non-null   float64
# dtypes: float64(4), int64(37)
# memory usage: 467.8 KB

# %%
#Check for correlations
checkcorrelation(data.select_dtypes(exclude = 'object').drop("SalePrice",axis = 1))

# %%
checkcorrelation(data.select_dtypes(exclude = 'object'), cluster = True)

# %%
checkcorrelation(data.select_dtypes(exclude = 'object'), target='SalePrice')
# Out:
#                    SalePrice
# SalePrice           1.000000
# OverallQual         0.790982
# TotalSF             0.782260
# GrLivArea           0.708624
# Total_sqr_footage   0.708047
# GarageCars          0.640409
# Total_Bathrooms     0.631731
# GarageArea          0.623431
# TotalBsmtSF         0.613581
# 1stFlrSF            0.605852
# YrBltAndRemod       0.576144
# FullBath            0.560664
# TotRmsAbvGrd        0.533723
# YearBuilt           0.522897
# YearRemodAdd        0.507101
# MasVnrArea          0.472614
# Fireplaces          0.466929
# Total_porch_sf      0.390993
# BsmtFinSF1          0.386420
# LotFrontage         0.349876
# WoodDeckSF          0.324413
# 2ndFlrSF            0.319334
# OpenPorchSF         0.315856
# HalfBath            0.284108
# LotArea             0.263843
# GarageYrBlt         0.261366
# BsmtFullBath        0.227122
# BsmtUnfSF           0.214479
# BedroomAbvGr        0.168213
# ScreenPorch         0.111447
# PoolArea            0.092404
# MoSold              0.046432
# 3SsnPorch           0.044584
# BsmtFinSF2         -0.011378
# BsmtHalfBath       -0.016844
# MiscVal            -0.021190
# LowQualFinSF       -0.025606
# YrSold             -0.028923
# OverallCond        -0.077856
# EnclosedPorch      -0.128578
# KitchenAbvGr       -0.135907

# %% [markdown]
# We see from correlation analysis that a lot of the numerical features are correlated. With this in mind, we can do PCA for numerical variables

# %% [markdown]
# #### PCA for numerical variables

# %%
PCA = PrincipalComponentAnalysis()
PCA.explain(data.select_dtypes(exclude='object').drop(columns=['SalePrice']))
# Out:
# [0.23996593 0.32163523 0.39287144 0.44689234 0.48964277 0.5262201
#  0.55650554 0.58586153 0.61487136 0.64242123 0.66914505 0.69563459
#  0.72102466 0.7460438  0.76991148 0.79314089 0.81528738 0.83637734
#  0.85618435 0.87563174 0.89324758 0.90970522 0.92491323 0.93919939
#  0.95089842 0.96113169 0.96991059 0.97738096 0.98451528 0.98993378
#  0.99401575 0.99750711 1.         1.         1.         1.
#  1.         1.         1.         1.        ]
# =====================================
# Number of Principal Components that explains 85% of variance:
# 19
# =====================================
# Loadings:
#                        PC_1      PC_2      PC_3      PC_4      PC_5      PC_6  \
# LotFrontage        0.143948  0.063889  0.148703  0.178814 -0.032673 -0.127724
# LotArea            0.099844  0.039202  0.211595  0.073694  0.036528 -0.077952
# OverallQual        0.251782 -0.053786 -0.145405  0.019680  0.089237  0.029061
# OverallCond       -0.059839  0.076172  0.097314 -0.094759  0.276664 -0.029587
# YearBuilt          0.189970 -0.286481 -0.258438 -0.074440 -0.091019  0.073015
# YearRemodAdd       0.170530 -0.171545 -0.245347 -0.099727  0.056181  0.226126
# MasVnrArea         0.162700 -0.019205 -0.017145  0.024601 -0.043215 -0.111369
# BsmtFinSF1         0.147724 -0.221170  0.350752 -0.149777 -0.173520 -0.035009
# TotalSF           -0.008146 -0.069160  0.021678 -0.071185  0.030376  0.027388
# Total_sqr_footage -0.033007 -0.067743 -0.011751 -0.058763  0.039222  0.014840
# Total_porch_sf     0.047826  0.076699 -0.132650 -0.012738 -0.023517 -0.075104
# Total_Bathrooms   -0.089974  0.004936 -0.015520 -0.053454  0.035546 -0.009620
#
#                       PC_19
# LotFrontage        0.179947
# LotArea            0.104773
# OverallQual        0.025247
# OverallCond       -0.306571
# YearBuilt          0.062933
# YearRemodAdd      -0.021699
# MasVnrArea        -0.037382
# BsmtFinSF1         0.033689
# BsmtFinSF2        -0.158220
# BsmtUnfSF         -0.030026
# TotalBsmtSF       -0.053398
# 1stFlrSF          -0.069415
# 2ndFlrSF           0.009969
# LowQualFinSF       0.204224
# GrLivArea         -0.023889
# BsmtFullBath      -0.049883
# BsmtHalfBath       0.305119
# FullBath           0.017214
# HalfBath           0.008351
# BedroomAbvGr      -0.067837
# KitchenAbvGr      -0.066662
# TotRmsAbvGrd      -0.080452
# Fireplaces         0.039136
# GarageYrBlt       -0.035878
# GarageCars         0.029068
# GarageArea         0.038896
# WoodDeckSF        -0.106143
# OpenPorchSF        0.094583
# EnclosedPorch      0.247676
# 3SsnPorch         -0.190217
# ScreenPorch       -0.009144
# PoolArea           0.066653
# MiscVal            0.103397
# MoSold             0.439311
# YrSold             0.574109
# YrBltAndRemod      0.031871
# TotalSF           -0.055870
# Total_sqr_footage -0.042173
# Total_porch_sf     0.012858
# Total_Bathrooms    0.028167

# %%
data.select_dtypes(exclude='object').drop(columns = ['SalePrice']).shape[1]
# Out:
# 40

# %% [markdown]
# With this, we can reduce the numeric variables from 40 variables to just 19

# %%
#This is for preprocessing later
#numeric = PCA.do(data.select_dtypes(exclude='object').drop(columns=['SalePrice']), n_components = 20, mode = 'train')
#numericcol = data.select_dtypes(exclude='object').drop(columns = ['SalePrice']).columns
#data = data.drop(columns = numericcol)
#data = pd.concat([data,numeric],axis = 1)
#data.info()

# %% [markdown]
# # Handling Categorical Variables

# %% [markdown]
# There are a lot of variables here that are categorical. Since there is a lot of them, first we can try to see which variables have a high missing value count. After that, we can try to remove variables that are greatly imbalanced since it will not help much during model inference due to lack of variance. Third, if the number of variables are still huge, we can reduce them using MCA.

# %% [markdown]
# First, select variables that are not considered in numerical data

# %%
data.select_dtypes(include=['object']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 44 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   object
#  1   MSZoning       1460 non-null   object
#  2   Street         1460 non-null   object
#  3   Alley          91 non-null     object
#  4   LotShape       1460 non-null   object
#  5   LandContour    1460 non-null   object
#  6   Utilities      1460 non-null   object
#  7   LotConfig      1460 non-null   object
#  8   LandSlope      1460 non-null   object
#  9   Neighborhood   1460 non-null   object
#  10  Condition1     1460 non-null   object
#  11  Condition2     1460 non-null   object
#  12  BldgType       1460 non-null   object
#  13  HouseStyle     1460 non-null   object
#  14  RoofStyle      1460 non-null   object
#  15  RoofMatl       1460 non-null   object
#  16  Exterior1st    1460 non-null   object
#  17  Exterior2nd    1460 non-null   object
#  18  MasVnrType     1460 non-null   object
#  19  ExterQual      1460 non-null   object
#  20  ExterCond      1460 non-null   object
#  21  Foundation     1460 non-null   object
#  22  BsmtQual       1423 non-null   object
#  23  BsmtCond       1423 non-null   object
#  24  BsmtExposure   1422 non-null   object
#  25  BsmtFinType1   1423 non-null   object
#  26  BsmtFinType2   1422 non-null   object
#  27  Heating        1460 non-null   object
#  28  HeatingQC      1460 non-null   object
#  29  CentralAir     1460 non-null   object
#  30  Electrical     1459 non-null   object
#  31  KitchenQual    1460 non-null   object
#  32  Functional     1460 non-null   object
#  33  FireplaceQu    770 non-null    object
#  34  GarageType     1379 non-null   object
#  35  GarageFinish   1379 non-null   object
#  36  GarageQual     1379 non-null   object
#  37  GarageCond     1379 non-null   object
#  38  PavedDrive     1460 non-null   object
#  39  PoolQC         7 non-null      object
#  40  Fence          281 non-null    object
#  41  MiscFeature    54 non-null     object
#  42  SaleType       1460 non-null   object
#  43  SaleCondition  1460 non-null   object
# dtypes: object(44)
# memory usage: 502.0+ KB

# %%
checkmissing(data.select_dtypes(include=['object']), threshold = 0.3)
# Out:
# Columns that has missing values:
# Alley           0.937671
# BsmtQual        0.025342
# BsmtCond        0.025342
# BsmtExposure    0.026027
# BsmtFinType1    0.025342
# BsmtFinType2    0.026027
# Electrical      0.000685
# FireplaceQu     0.472603
# GarageType      0.055479
# GarageFinish    0.055479
# GarageQual      0.055479
# GarageCond      0.055479
# PoolQC          0.995205
# Fence           0.807534
# MiscFeature     0.963014
# dtype: float64
# Columns that has large missing values:
# PoolQC         0.995205
# MiscFeature    0.963014
# Alley          0.937671
# Fence          0.807534
# FireplaceQu    0.472603
# dtype: float64

# %% [markdown]
# Immediately dropped (PoolQC, MiscFeature, Alley, Fence). Because even if we have them imputed, most of the value will be the same. They do not give much information.

# %%
data.drop(columns = ['PoolQC','MiscFeature','Alley','Fence'], axis = 1, inplace = True)

# %% [markdown]
# #### Categorical variables with high cardinality

# %% [markdown]
# Generally, categorical variables with high cardinality are dropped. Here, I don't dropped it because eventually we will use MCA.

# %% [markdown]
# #### Evaluate count on variables left

# %%
checkallcatvaluecounts(data.select_dtypes(include=['object']))
# Out:
# =====================================
# MSSubClass
# 20     0.367123
# 60     0.204795
# 50     0.098630
# 120    0.059589
# 30     0.047260
# 160    0.043151
# 70     0.041096
# 80     0.039726
# 90     0.035616
# 190    0.020548
# 85     0.013699
# 75     0.010959
# 45     0.008219
# 180    0.006849
# 40     0.002740
# Name: proportion, dtype: float64
# =====================================
# =====================================
# MSZoning
# RL         0.788356
# RM         0.149315
# FV         0.044521
# RH         0.010959
# C (all)    0.006849
# Name: proportion, dtype: float64
# =====================================
# =====================================
# Street
# Pave    0.99589
# Grvl    0.00411
# Name: proportion, dtype: float64
# =====================================
# =====================================
# LotShape
# Reg    0.633562
# IR1    0.331507
# IR2    0.028082
# IR3    0.006849
# Name: proportion, dtype: float64
# =====================================
# =====================================
# LandContour
# Lvl    0.897945
# Bnk    0.043151
# HLS    0.034247
# Low    0.024658
# Name: proportion, dtype: float64
# =====================================
# =====================================
# Utilities
# AllPub    0.999315
# NoSeWa    0.000685
# Name: proportion, dtype: float64
# =====================================
# =====================================
# LotConfig
# Inside     0.720548
# Corner     0.180137
# CulDSac    0.064384
# FR2        0.032192
# FR3        0.002740
# Name: proportion, dtype: float64
# =====================================
# =====================================
# LandSlope
# Gtl    0.946575
# Mod    0.044521
# Sev    0.008904
# Name: proportion, dtype: float64
# =====================================
# =====================================
# Neighborhood
# NAmes      0.154110
# CollgCr    0.102740
# OldTown    0.077397
# Edwards    0.068493
# Somerst    0.058904
# Gilbert    0.054110
# NridgHt    0.052740
# Sawyer     0.050685
# NWAmes     0.050000
# SawyerW    0.040411
# BrkSide    0.039726
# Crawfor    0.034932
# Mitchel    0.033562
# NoRidge    0.028082
# Timber     0.026027
# IDOTRR     0.025342
# ClearCr    0.019178
# StoneBr    0.017123
# SWISU      0.017123
# MeadowV    0.011644
# Blmngtn    0.011644
# BrDale     0.010959
# Veenker    0.007534
# NPkVill    0.006164
# Blueste    0.001370
# Name: proportion, dtype: float64
# =====================================
# =====================================
# Condition1
# Norm      0.863014
# Feedr     0.055479
# Artery    0.032877
# RRAn      0.017808
# PosN      0.013014
# RRAe      0.007534
# PosA      0.005479
# RRNn      0.003425
# RRNe      0.001370
# Name: proportion, dtype: float64
# =====================================
# =====================================
# Condition2
# Norm      0.989726
# Feedr     0.004110
# Artery    0.001370
# RRNn      0.001370
# PosN      0.001370
# PosA      0.000685
# RRAn      0.000685
# RRAe      0.000685
# Name: proportion, dtype: float64
# =====================================
# =====================================
# BldgType
# 1Fam      0.835616
# TwnhsE    0.078082
# Duplex    0.035616
# Twnhs     0.029452
# 2fmCon    0.021233
# Name: proportion, dtype: float64
# =====================================
# =====================================
# HouseStyle
# 1Story    0.497260
# 2Story    0.304795
# 1.5Fin    0.105479
# SLvl      0.044521
# SFoyer    0.025342
# 1.5Unf    0.009589
# 2.5Unf    0.007534
# 2.5Fin    0.005479
# Name: proportion, dtype: float64
# =====================================
# =====================================
# RoofStyle
# Gable      0.781507
# Hip        0.195890
# Flat       0.008904
# Gambrel    0.007534
# Mansard    0.004795
# Shed       0.001370
# Name: proportion, dtype: float64
# =====================================
# =====================================
# RoofMatl
# CompShg    0.982192
# Tar&Grv    0.007534
# WdShngl    0.004110
# WdShake    0.003425
# Metal      0.000685
# Membran    0.000685
# Roll       0.000685
# ClyTile    0.000685
# Name: proportion, dtype: float64
# =====================================
# =====================================
# Exterior1st
# VinylSd    0.352740
# HdBoard    0.152055
# MetalSd    0.150685
# Wd Sdng    0.141096
# Plywood    0.073973
# CemntBd    0.041781
# BrkFace    0.034247
# WdShing    0.017808
# Stucco     0.017123
# AsbShng    0.013699
# BrkComm    0.001370
# Stone      0.001370
# AsphShn    0.000685
# ImStucc    0.000685
# CBlock     0.000685
# Name: proportion, dtype: float64
# =====================================
# =====================================
# Exterior2nd
# VinylSd    0.345205
# MetalSd    0.146575
# HdBoard    0.141781
# Wd Sdng    0.134932
# Plywood    0.097260
# CmentBd    0.041096
# Wd Shng    0.026027
# Stucco     0.017808
# BrkFace    0.017123
# AsbShng    0.013699
# ImStucc    0.006849
# Brk Cmn    0.004795
# Stone      0.003425
# AsphShn    0.002055
# Other      0.000685
# CBlock     0.000685
# Name: proportion, dtype: float64
# =====================================
# =====================================
# MasVnrType
# None       0.593836
# BrkFace    0.308219
# Stone      0.087671
# BrkCmn     0.010274
# Name: proportion, dtype: float64
# =====================================
# =====================================
# ExterQual
# TA    0.620548
# Gd    0.334247
# Ex    0.035616
# Fa    0.009589
# Name: proportion, dtype: float64
# =====================================
# =====================================
# ExterCond
# TA    0.878082
# Gd    0.100000
# Fa    0.019178
# Ex    0.002055
# Po    0.000685
# Name: proportion, dtype: float64
# =====================================
# =====================================
# Foundation
# PConc     0.443151
# CBlock    0.434247
# BrkTil    0.100000
# Slab      0.016438
# Stone     0.004110
# Wood      0.002055
# Name: proportion, dtype: float64
# =====================================
# =====================================
# BsmtQual
# TA    0.456079
# Gd    0.434294
# Ex    0.085032
# Fa    0.024596
# Name: proportion, dtype: float64
# =====================================
# =====================================
# BsmtCond
# TA    0.921293
# Gd    0.045678
# Fa    0.031623
# Po    0.001405
# Name: proportion, dtype: float64
# =====================================
# =====================================
# BsmtExposure
# No    0.670183
# Av    0.155415
# Gd    0.094233
# Mn    0.080169
# Name: proportion, dtype: float64
# =====================================
# =====================================
# BsmtFinType1
# Unf    0.302178
# GLQ    0.293746
# ALQ    0.154603
# BLQ    0.104006
# Rec    0.093465
# LwQ    0.052003
# Name: proportion, dtype: float64
# =====================================
# =====================================
# BsmtFinType2
# Unf    0.883263
# Rec    0.037975
# LwQ    0.032349
# BLQ    0.023207
# ALQ    0.013361
# GLQ    0.009845
# Name: proportion, dtype: float64
# =====================================
# =====================================
# Heating
# GasA     0.978082
# GasW     0.012329
# Grav     0.004795
# Wall     0.002740
# OthW     0.001370
# Floor    0.000685
# Name: proportion, dtype: float64
# =====================================
# =====================================
# HeatingQC
# Ex    0.507534
# TA    0.293151
# Gd    0.165068
# Fa    0.033562
# Po    0.000685
# Name: proportion, dtype: float64
# =====================================
# =====================================
# CentralAir
# Y    0.934932
# N    0.065068
# Name: proportion, dtype: float64
# =====================================
# =====================================
# Electrical
# SBrkr    0.914325
# FuseA    0.064428
# FuseF    0.018506
# FuseP    0.002056
# Mix      0.000685
# Name: proportion, dtype: float64
# =====================================
# =====================================
# KitchenQual
# TA    0.503425
# Gd    0.401370
# Ex    0.068493
# Fa    0.026712
# Name: proportion, dtype: float64
# =====================================
# =====================================
# Functional
# Typ     0.931507
# Min2    0.023288
# Min1    0.021233
# Mod     0.010274
# Maj1    0.009589
# Maj2    0.003425
# Sev     0.000685
# Name: proportion, dtype: float64
# =====================================
# =====================================
# FireplaceQu
# Gd    0.493506
# TA    0.406494
# Fa    0.042857
# Ex    0.031169
# Po    0.025974
# Name: proportion, dtype: float64
# =====================================
# =====================================
# GarageType
# Attchd     0.630892
# Detchd     0.280638
# BuiltIn    0.063814
# Basment    0.013778
# CarPort    0.006526
# 2Types     0.004351
# Name: proportion, dtype: float64
# =====================================
# =====================================
# GarageFinish
# Unf    0.438724
# RFn    0.306019
# Fin    0.255257
# Name: proportion, dtype: float64
# =====================================
# =====================================
# GarageQual
# TA    0.950689
# Fa    0.034808
# Gd    0.010152
# Ex    0.002175
# Po    0.002175
# Name: proportion, dtype: float64
# =====================================
# =====================================
# GarageCond
# TA    0.961566
# Fa    0.025381
# Gd    0.006526
# Po    0.005076
# Ex    0.001450
# Name: proportion, dtype: float64
# =====================================
# =====================================
# PavedDrive
# Y    0.917808
# N    0.061644
# P    0.020548
# Name: proportion, dtype: float64
# =====================================
# =====================================
# SaleType
# WD       0.867808
# New      0.083562
# COD      0.029452
# ConLD    0.006164
# ConLI    0.003425
# ConLw    0.003425
# CWD      0.002740
# Oth      0.002055
# Con      0.001370
# Name: proportion, dtype: float64
# =====================================
# =====================================
# SaleCondition
# Normal     0.820548
# Partial    0.085616
# Abnorml    0.069178
# Family     0.013699
# Alloca     0.008219
# AdjLand    0.002740
# Name: proportion, dtype: float64
# =====================================

# %% [markdown]
# #### dropped imbalanced categorical columns

# %% [markdown]
# Variables that are highly imbalanced are Street, Utilities, LandSlope, Condition2, RoofMatl, BsmtCond, Heating, CentralAir, Electrical, Functional, GarageQual, GarageCond, and PavedDrive.

# %%
imbalancedcatcol = ['Street','Utilities','LandSlope','Condition2','RoofMatl','BsmtCond','Heating',
                    'CentralAir','Electrical','Functional','GarageQual','GarageCond','PavedDrive']
data.drop(columns = imbalancedcatcol, inplace = True)

# %%
#check missing again
data.select_dtypes(include=['object']).info()
checkmissing(data.select_dtypes(include=['object']), threshold = 0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   object
#  1   MSZoning       1460 non-null   object
#  2   LotShape       1460 non-null   object
#  3   LandContour    1460 non-null   object
#  4   LotConfig      1460 non-null   object
#  5   Neighborhood   1460 non-null   object
#  6   Condition1     1460 non-null   object
#  7   BldgType       1460 non-null   object
#  8   HouseStyle     1460 non-null   object
#  9   RoofStyle      1460 non-null   object
#  10  Exterior1st    1460 non-null   object
#  11  Exterior2nd    1460 non-null   object
#  12  MasVnrType     1460 non-null   object
#  13  ExterQual      1460 non-null   object
#  14  ExterCond      1460 non-null   object
#  15  Foundation     1460 non-null   object
#  16  BsmtQual       1423 non-null   object
#  17  BsmtExposure   1422 non-null   object
#  18  BsmtFinType1   1423 non-null   object
#  19  BsmtFinType2   1422 non-null   object
#  20  HeatingQC      1460 non-null   object
#  21  KitchenQual    1460 non-null   object
#  22  FireplaceQu    770 non-null    object
#  23  GarageType     1379 non-null   object
#  24  GarageFinish   1379 non-null   object
#  25  SaleType       1460 non-null   object
#  26  SaleCondition  1460 non-null   object
# dtypes: object(27)
# memory usage: 308.1+ KB
# Columns that has missing values:
# BsmtQual        0.025342
# BsmtExposure    0.026027
# BsmtFinType1    0.025342
# BsmtFinType2    0.026027
# FireplaceQu     0.472603
# GarageType      0.055479
# GarageFinish    0.055479
# dtype: float64

# %% [markdown]
# ## Now, focus on evaluating missing values in categorical

# %% [markdown]
# #### BsmtQual & BsmtExposure

# %%
checkmissing(data.select_dtypes(include=['object'])[['BsmtQual','BsmtExposure']], threshold = 0)
# Out:
# Columns that has missing values:
# BsmtQual        0.025342
# BsmtExposure    0.026027
# dtype: float64

# %% [markdown]
# For these two, it's weird that the number of missing is not the same. Thus, it cannot be solely due to misinterpreted "None"

# %%
data[data['BsmtQual'].isna()][['BsmtFinSF1','BsmtUnfSF']]
# Out:
#       BsmtFinSF1  BsmtUnfSF
# 17             0          0
# 39             0          0
# 90             0          0
# 102            0          0
# 156            0          0
# 182            0          0
# 259            0          0
# 342            0          0
# 362            0          0
# 371            0          0
# 392            0          0
# 520            0          0
# 532            0          0
# 533            0          0
# 553            0          0
# 646            0          0
# 705            0          0
# 736            0          0
# 749            0          0
# 778            0          0
# 868            0          0
# 894            0          0
# 897            0          0
# 984            0          0
# 1000           0          0
# 1011           0          0
# 1035           0          0
# 1045           0          0
# 1048           0          0
# 1049           0          0
# 1090           0          0
# 1179           0          0
# 1216           0          0
# 1218           0          0
# 1232           0          0
# 1321           0          0
# 1412           0          0

# %%
data[data['BsmtExposure'].isna()][['BsmtFinSF1','BsmtUnfSF']]
# Out:
#       BsmtFinSF1  BsmtUnfSF
# 17             0          0
# 39             0          0
# 90             0          0
# 102            0          0
# 156            0          0
# 182            0          0
# 259            0          0
# 342            0          0
# 362            0          0
# 371            0          0
# 392            0          0
# 520            0          0
# 532            0          0
# 533            0          0
# 553            0          0
# 646            0          0
# 705            0          0
# 736            0          0
# 749            0          0
# 778            0          0
# 868            0          0
# 894            0          0
# 897            0          0
# 948            0        936
# 984            0          0
# 1000           0          0
# 1011           0          0
# 1035           0          0
# 1045           0          0
# 1048           0          0
# 1049           0          0
# 1090           0          0
# 1179           0          0
# 1216           0          0
# 1218           0          0
# 1232           0          0
# 1321           0          0
# 1412           0          0

# %% [markdown]
# Above shows that the problem is on mismatch between the two variables, not the existing of the basements. Also, it shows that when the BsmtQual & BsmtExposure are NaN, most of the time there really is no basement. If so, we can fill them with no Basement.

# %%
data['BsmtQual'].fillna('NA', inplace = True)
data['BsmtExposure'].fillna('NA',inplace = True)
# Out:
# C:\Windows\Temp\ipykernel_14232\1277386514.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['BsmtQual'].fillna('NA', inplace = True)
# C:\Windows\Temp\ipykernel_14232\1277386514.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['BsmtExposure'].fillna('NA',inplace = True)

# %% [markdown]
# Since index 948 is a bit conflicting, we can drop this one row

# %%
data = data.drop(index = 948).reset_index(drop = True)

# %% [markdown]
# #### BsmtFinType1 & BsmtFinType2

# %% [markdown]
# We just dropped a row previously. Let's recheck the missing values

# %%
checkmissing(data.select_dtypes(include=['object']), threshold = 0)
# Out:
# Columns that has missing values:
# BsmtFinType1    0.025360
# BsmtFinType2    0.026045
# FireplaceQu     0.472927
# GarageType      0.055517
# GarageFinish    0.055517
# dtype: float64

# %% [markdown]
# We need to check this like we check BsmtQual and BsmtExposure previously

# %%
data[data['BsmtFinType1'].isna()][['BsmtFinSF1','BsmtUnfSF']]
# Out:
#       BsmtFinSF1  BsmtUnfSF
# 17             0          0
# 39             0          0
# 90             0          0
# 102            0          0
# 156            0          0
# 182            0          0
# 259            0          0
# 342            0          0
# 362            0          0
# 371            0          0
# 392            0          0
# 520            0          0
# 532            0          0
# 533            0          0
# 553            0          0
# 646            0          0
# 705            0          0
# 736            0          0
# 749            0          0
# 778            0          0
# 868            0          0
# 894            0          0
# 897            0          0
# 983            0          0
# 999            0          0
# 1010           0          0
# 1034           0          0
# 1044           0          0
# 1047           0          0
# 1048           0          0
# 1089           0          0
# 1178           0          0
# 1215           0          0
# 1217           0          0
# 1231           0          0
# 1320           0          0
# 1411           0          0

# %%
data[data['BsmtFinType2'].isna()][['BsmtFinSF2','BsmtUnfSF']]
# Out:
#       BsmtFinSF2  BsmtUnfSF
# 17             0          0
# 39             0          0
# 90             0          0
# 102            0          0
# 156            0          0
# 182            0          0
# 259            0          0
# 332          479       1603
# 342            0          0
# 362            0          0
# 371            0          0
# 392            0          0
# 520            0          0
# 532            0          0
# 533            0          0
# 553            0          0
# 646            0          0
# 705            0          0
# 736            0          0
# 749            0          0
# 778            0          0
# 868            0          0
# 894            0          0
# 897            0          0
# 983            0          0
# 999            0          0
# 1010           0          0
# 1034           0          0
# 1044           0          0
# 1047           0          0
# 1048           0          0
# 1089           0          0
# 1178           0          0
# 1215           0          0
# 1217           0          0
# 1231           0          0
# 1320           0          0
# 1411           0          0

# %% [markdown]
# Again, index 332 is weird. Let's fill it with "Unf" and fill the rest of the NA with "NA".

# %%
data.loc[332,'BsmtFinType2'] = 'Unf'

# %%
data[['BsmtFinType1','BsmtFinType2']] = data[['BsmtFinType1','BsmtFinType2']].fillna('NA')

# %% [markdown]
# #### FireplaceQu

# %%
data[data['FireplaceQu'].isna()][['FireplaceQu','Fireplaces']]
# Out:
#      FireplaceQu  Fireplaces
# 0            NaN           0
# 5            NaN           0
# 10           NaN           0
# 12           NaN           0
# 15           NaN           0
# ...          ...         ...
# 1451         NaN           0
# 1452         NaN           0
# 1453         NaN           0
# 1457         NaN           0
# 1458         NaN           0
#
# [690 rows x 2 columns]

# %%
data[(data['FireplaceQu'].isna()) & (data['Fireplaces'] > 0)][['FireplaceQu','Fireplaces']]
# Out:
# Empty DataFrame
# Columns: [FireplaceQu, Fireplaces]
# Index: []

# %%
data['FireplaceQu'].fillna('NA', inplace = True)
# Out:
# C:\Windows\Temp\ipykernel_14232\871519053.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['FireplaceQu'].fillna('NA', inplace = True)

# %% [markdown]
# #### GarageType & GarageFinish

# %%
print(len(data[data['GarageYrBlt'] == 0]))
print(data['GarageType'].isna().sum())
print(data['GarageFinish'].isna().sum())
# Out:
# 81
# 81
# 81

# %%
data['GarageType'].fillna('NA', inplace = True)
data['GarageFinish'].fillna('NA',inplace = True)
# Out:
# C:\Windows\Temp\ipykernel_14232\701484985.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['GarageType'].fillna('NA', inplace = True)
# C:\Windows\Temp\ipykernel_14232\701484985.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['GarageFinish'].fillna('NA',inplace = True)

# %% [markdown]
# #### Feature Engineering & Reduction (With MCA)

# %% [markdown]
# First, do feature engineering following reference.

# %%
### In this phase, do feature engineering for categorical columns

data['haspool'] = data['PoolArea'].apply(lambda i: "Yes" if i > 0 else "No")
data['has2ndfloor'] = data['2ndFlrSF'].apply(lambda i: "Yes" if i > 0 else "No")
data['hasgarage'] = data['GarageArea'].apply(lambda i: "Yes" if i > 0 else "No")
data['hasbsmt'] = data['TotalBsmtSF'].apply(lambda i: "Yes" if i > 0 else "No")
data['hasfireplace'] = data['Fireplaces'].apply(lambda i: "Yes" if i > 0 else "No")

# %%
#Recheck whether the engineered variables are imbalanced or not
checkallcatvaluecounts(data[['haspool','has2ndfloor','hasgarage','hasbsmt','hasfireplace']])
# Out:
# =====================================
# haspool
# No     0.995202
# Yes    0.004798
# Name: proportion, dtype: float64
# =====================================
# =====================================
# has2ndfloor
# No     0.568197
# Yes    0.431803
# Name: proportion, dtype: float64
# =====================================
# =====================================
# hasgarage
# Yes    0.944483
# No     0.055517
# Name: proportion, dtype: float64
# =====================================
# =====================================
# hasbsmt
# Yes    0.97464
# No     0.02536
# Name: proportion, dtype: float64
# =====================================
# =====================================
# hasfireplace
# Yes    0.527073
# No     0.472927
# Name: proportion, dtype: float64
# =====================================

# %%
#delete haspool, hasgarage, and hasbsmt
data.drop(columns = ['haspool','hasgarage','hasbsmt'],inplace = True)

# %% [markdown]
# #### MCA for categorical variables

# %% [markdown]
# One of MCA assumption is that the variables must have more than two categories within. Thus, first set aside the categories that we don't pay attention to.

# %%
data['has2ndfloor'] = data['has2ndfloor'].astype('object')
data['hasfireplace'] = data['hasfireplace'].astype('object')

# %%
checkallcatvaluecounts(data.select_dtypes(include=['object']))
# Out:
# =====================================
# MSSubClass
# 20     0.367375
# 60     0.204249
# 50     0.098698
# 120    0.059630
# 30     0.047293
# 160    0.043180
# 70     0.041124
# 80     0.039753
# 90     0.035641
# 190    0.020562
# 85     0.013708
# 75     0.010966
# 45     0.008225
# 180    0.006854
# 40     0.002742
# Name: proportion, dtype: float64
# =====================================
# =====================================
# MSZoning
# RL         0.788211
# RM         0.149417
# FV         0.044551
# RH         0.010966
# C (all)    0.006854
# Name: proportion, dtype: float64
# =====================================
# =====================================
# LotShape
# Reg    0.633996
# IR1    0.331049
# IR2    0.028101
# IR3    0.006854
# Name: proportion, dtype: float64
# =====================================
# =====================================
# LandContour
# Lvl    0.897875
# Bnk    0.043180
# HLS    0.034270
# Low    0.024674
# Name: proportion, dtype: float64
# =====================================
# =====================================
# LotConfig
# Inside     0.720356
# Corner     0.180260
# CulDSac    0.064428
# FR2        0.032214
# FR3        0.002742
# Name: proportion, dtype: float64
# =====================================
# =====================================
# Neighborhood
# NAmes      0.154215
# CollgCr    0.102125
# OldTown    0.077450
# Edwards    0.068540
# Somerst    0.058944
# Gilbert    0.054147
# NridgHt    0.052776
# Sawyer     0.050720
# NWAmes     0.050034
# SawyerW    0.040439
# BrkSide    0.039753
# Crawfor    0.034955
# Mitchel    0.033585
# NoRidge    0.028101
# Timber     0.026045
# IDOTRR     0.025360
# ClearCr    0.019191
# StoneBr    0.017135
# SWISU      0.017135
# MeadowV    0.011652
# Blmngtn    0.011652
# BrDale     0.010966
# Veenker    0.007539
# NPkVill    0.006169
# Blueste    0.001371
# Name: proportion, dtype: float64
# =====================================
# =====================================
# Condition1
# Norm      0.862920
# Feedr     0.055517
# Artery    0.032899
# RRAn      0.017820
# PosN      0.013023
# RRAe      0.007539
# PosA      0.005483
# RRNn      0.003427
# RRNe      0.001371
# Name: proportion, dtype: float64
# =====================================
# =====================================
# BldgType
# 1Fam      0.835504
# TwnhsE    0.078136
# Duplex    0.035641
# Twnhs     0.029472
# 2fmCon    0.021247
# Name: proportion, dtype: float64
# =====================================
# =====================================
# HouseStyle
# 1Story    0.497601
# 2Story    0.304318
# 1.5Fin    0.105552
# SLvl      0.044551
# SFoyer    0.025360
# 1.5Unf    0.009596
# 2.5Unf    0.007539
# 2.5Fin    0.005483
# Name: proportion, dtype: float64
# =====================================
# =====================================
# RoofStyle
# Gable      0.781357
# Hip        0.196025
# Flat       0.008910
# Gambrel    0.007539
# Mansard    0.004798
# Shed       0.001371
# Name: proportion, dtype: float64
# =====================================
# =====================================
# Exterior1st
# VinylSd    0.352296
# HdBoard    0.152159
# MetalSd    0.150788
# Wd Sdng    0.141193
# Plywood    0.074023
# CemntBd    0.041809
# BrkFace    0.034270
# WdShing    0.017820
# Stucco     0.017135
# AsbShng    0.013708
# BrkComm    0.001371
# Stone      0.001371
# AsphShn    0.000685
# ImStucc    0.000685
# CBlock     0.000685
# Name: proportion, dtype: float64
# =====================================
# =====================================
# Exterior2nd
# VinylSd    0.344757
# MetalSd    0.146676
# HdBoard    0.141878
# Wd Sdng    0.135024
# Plywood    0.097327
# CmentBd    0.041124
# Wd Shng    0.026045
# Stucco     0.017820
# BrkFace    0.017135
# AsbShng    0.013708
# ImStucc    0.006854
# Brk Cmn    0.004798
# Stone      0.003427
# AsphShn    0.002056
# Other      0.000685
# CBlock     0.000685
# Name: proportion, dtype: float64
# =====================================
# =====================================
# MasVnrType
# None       0.594243
# BrkFace    0.307745
# Stone      0.087731
# BrkCmn     0.010281
# Name: proportion, dtype: float64
# =====================================
# =====================================
# ExterQual
# TA    0.620973
# Gd    0.333790
# Ex    0.035641
# Fa    0.009596
# Name: proportion, dtype: float64
# =====================================
# =====================================
# ExterCond
# TA    0.877999
# Gd    0.100069
# Fa    0.019191
# Ex    0.002056
# Po    0.000685
# Name: proportion, dtype: float64
# =====================================
# =====================================
# Foundation
# PConc     0.442769
# CBlock    0.434544
# BrkTil    0.100069
# Slab      0.016450
# Stone     0.004112
# Wood      0.002056
# Name: proportion, dtype: float64
# =====================================
# =====================================
# BsmtQual
# TA    0.444825
# Gd    0.422892
# Ex    0.082934
# NA    0.025360
# Fa    0.023989
# Name: proportion, dtype: float64
# =====================================
# =====================================
# BsmtExposure
# No    0.653187
# Av    0.151474
# Gd    0.091844
# Mn    0.078136
# NA    0.025360
# Name: proportion, dtype: float64
# =====================================
# =====================================
# BsmtFinType1
# Unf    0.294037
# GLQ    0.286498
# ALQ    0.150788
# BLQ    0.101439
# Rec    0.091158
# LwQ    0.050720
# NA     0.025360
# Name: proportion, dtype: float64
# =====================================
# =====================================
# BsmtFinType2
# Unf    0.860864
# Rec    0.037012
# LwQ    0.031528
# NA     0.025360
# BLQ    0.022618
# ALQ    0.013023
# GLQ    0.009596
# Name: proportion, dtype: float64
# =====================================
# =====================================
# HeatingQC
# Ex    0.507197
# TA    0.293352
# Gd    0.165182
# Fa    0.033585
# Po    0.000685
# Name: proportion, dtype: float64
# =====================================
# =====================================
# KitchenQual
# TA    0.503770
# Gd    0.400960
# Ex    0.068540
# Fa    0.026731
# Name: proportion, dtype: float64
# =====================================
# =====================================
# FireplaceQu
# NA    0.472927
# Gd    0.260452
# TA    0.213845
# Fa    0.022618
# Ex    0.016450
# Po    0.013708
# Name: proportion, dtype: float64
# =====================================
# =====================================
# GarageType
# Attchd     0.595613
# Detchd     0.265250
# BuiltIn    0.060315
# NA         0.055517
# Basment    0.013023
# CarPort    0.006169
# 2Types     0.004112
# Name: proportion, dtype: float64
# =====================================
# =====================================
# GarageFinish
# Unf    0.414668
# RFn    0.288554
# Fin    0.241261
# NA     0.055517
# Name: proportion, dtype: float64
# =====================================
# =====================================
# SaleType
# WD       0.867718
# New      0.083619
# COD      0.029472
# ConLD    0.006169
# ConLI    0.003427
# ConLw    0.003427
# CWD      0.002742
# Oth      0.002056
# Con      0.001371
# Name: proportion, dtype: float64
# =====================================
# =====================================
# SaleCondition
# Normal     0.820425
# Partial    0.085675
# Abnorml    0.069225
# Family     0.013708
# Alloca     0.008225
# AdjLand    0.002742
# Name: proportion, dtype: float64
# =====================================
# =====================================
# has2ndfloor
# No     0.568197
# Yes    0.431803
# Name: proportion, dtype: float64
# =====================================
# =====================================
# hasfireplace
# Yes    0.527073
# No     0.472927
# Name: proportion, dtype: float64
# =====================================

# %% [markdown]
# only the engineered variables are new variables

# %%
engineeredcatvar = data[['has2ndfloor','hasfireplace']]
data.drop(columns = ['has2ndfloor','hasfireplace'], inplace = True)

# %%
#Do the MCA
MCA = MultipleCorrespondenceAnalysis()
MCA.explain(data.select_dtypes(include = ['object']))
# Out:
#           eigenvalue % of variance % of variance (cumulative)
# component
# 0              0.318         4.94%                      4.94%
# 1              0.196         3.04%                      7.98%
# 2              0.180         2.80%                     10.78%
# 3              0.134         2.09%                     12.86%
# 4              0.129         2.01%                     14.87%
# 5              0.109         1.70%                     16.57%
# 4     0.111747  0.297687  0.046283 -0.093264  0.411086 -0.085513  0.226330
# ...        ...       ...       ...       ...       ...       ...       ...
# 1454 -0.171313  0.101626  0.105941 -0.174451 -0.105204  0.028038 -0.095505
# 1455 -0.163799 -0.259631 -0.118538 -0.049508  0.260406  0.047562 -0.066743
# 1456 -0.160365 -0.055321 -0.354973 -0.118207  0.521182  0.376467  0.409019
# 1457  0.274622  0.075207  0.127610 -0.169848  0.111661  0.119343  0.018826
# 1458  0.154635 -0.050218 -0.171871  0.027566 -0.228159 -0.185648  0.002455
#
# [1459 rows x 27 columns]

# %% [markdown]
# Using MCA does not capture the whole variance of the data. For this reason, we will just encode the data and pass it to the model

# %%
numeric = PCA.do(data.select_dtypes(exclude='object').drop(columns=['SalePrice']), n_components = 20, mode = 'train')
numericcol = data.select_dtypes(exclude='object').drop(columns = ['SalePrice']).columns
data = data.drop(columns = numericcol)
data = pd.concat([data,numeric],axis = 1)
data.info()

data = pd.concat([data, engineeredcatvar], axis = 1)
data = pd.get_dummies(data)
data.to_csv('trainpreprocessed.csv', index = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 48 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1459 non-null   object
#  1   MSZoning       1459 non-null   object
#  2   LotShape       1459 non-null   object
#  3   LandContour    1459 non-null   object
#  4   LotConfig      1459 non-null   object
#  5   Neighborhood   1459 non-null   object
#  6   Condition1     1459 non-null   object
#  7   BldgType       1459 non-null   object
#  8   HouseStyle     1459 non-null   object
#  9   RoofStyle      1459 non-null   object
#  10  Exterior1st    1459 non-null   object
#  11  Exterior2nd    1459 non-null   object
#  12  MasVnrType     1459 non-null   object
#  13  ExterQual      1459 non-null   object
#  14  ExterCond      1459 non-null   object
#  15  Foundation     1459 non-null   object
#  16  BsmtQual       1459 non-null   object
#  17  BsmtExposure   1459 non-null   object
#  18  BsmtFinType1   1459 non-null   object
#  19  BsmtFinType2   1459 non-null   object
#  20  HeatingQC      1459 non-null   object
#  21  KitchenQual    1459 non-null   object
#  22  FireplaceQu    1459 non-null   object
#  23  GarageType     1459 non-null   object
#  24  GarageFinish   1459 non-null   object
#  25  SaleType       1459 non-null   object
#  26  SaleCondition  1459 non-null   object
#  27  SalePrice      1459 non-null   int64
#  28  PC_1           1459 non-null   float64
#  29  PC_2           1459 non-null   float64
#  30  PC_3           1459 non-null   float64
#  31  PC_4           1459 non-null   float64
#  32  PC_5           1459 non-null   float64
#  33  PC_6           1459 non-null   float64
#  34  PC_7           1459 non-null   float64
#  35  PC_8           1459 non-null   float64
#  36  PC_9           1459 non-null   float64
#  37  PC_10          1459 non-null   float64
#  38  PC_11          1459 non-null   float64
#  39  PC_12          1459 non-null   float64
#  40  PC_13          1459 non-null   float64
#  41  PC_14          1459 non-null   float64
#  42  PC_15          1459 non-null   float64
#  43  PC_16          1459 non-null   float64
#  44  PC_17          1459 non-null   float64
#  45  PC_18          1459 non-null   float64
#  46  PC_19          1459 non-null   float64
#  47  PC_20          1459 non-null   float64
# dtypes: float64(20), int64(1), object(27)
# memory usage: 547.2+ KB
